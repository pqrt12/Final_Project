# %%
import pandas as pd

# %%
players_df = pd.read_csv('players.csv')

# %%
map_1_df = players_df[[
    'date',
    'player_name',
    'team',
    'opponent', 
    'player_id', 
    'match_id',
    'event_id',
    'best_of',
    'map_1',
    'm1_kills',
    'm1_assists',
    'm1_deaths',
    'm1_hs',
    'm1_flash_assists',
    'm1_kast',
    'm1_kddiff',
    'm1_adr',
    'm1_fkdiff',
    'm1_rating']].copy()
map_1_df
# Out:
#               date player_name           team       opponent  player_id  \
# 0       2020-02-26      Brehze  Evil Geniuses         Liquid       9136
# 1       2020-02-26        CeRq  Evil Geniuses         Liquid      11219
# 2       2020-02-26       EliGE         Liquid  Evil Geniuses       8738
# 3       2020-02-26       Ethan  Evil Geniuses         Liquid      10671
# 4       2020-02-26         NAF         Liquid  Evil Geniuses       8520
# ...            ...         ...            ...            ...        ...
# 383312  2015-10-07      kIMERA        ExAequo      RIP Fonty       7607
# 383313  2015-10-07   morphiw0w        ExAequo      RIP Fonty       9752
# 383314  2015-10-07     overfly      RIP Fonty        ExAequo       7698
# 383315  2015-10-07     simozor      RIP Fonty        ExAequo       9753
# 383316  2015-10-07       xullE      RIP Fonty        ExAequo       9754
#
#         match_id  event_id  best_of        map_1  m1_kills  m1_assists  \
# ...

# %%
map_1_df = map_1_df.dropna()

# %%
map_2_df = players_df[[
    'date',
    'player_name',
    'team',
    'opponent', 
    'player_id', 
    'match_id',
    'event_id',
    'best_of',
    'map_2',
    'm2_kills',
    'm2_assists',
    'm2_deaths',
    'm2_hs',
    'm2_flash_assists',
    'm2_kast',
    'm2_kddiff',
    'm2_adr',
    'm2_fkdiff',
    'm2_rating']].copy()
map_2_df
# Out:
#               date player_name           team       opponent  player_id  \
# 0       2020-02-26      Brehze  Evil Geniuses         Liquid       9136
# 1       2020-02-26        CeRq  Evil Geniuses         Liquid      11219
# 2       2020-02-26       EliGE         Liquid  Evil Geniuses       8738
# 3       2020-02-26       Ethan  Evil Geniuses         Liquid      10671
# 4       2020-02-26         NAF         Liquid  Evil Geniuses       8520
# ...            ...         ...            ...            ...        ...
# 383312  2015-10-07      kIMERA        ExAequo      RIP Fonty       7607
# 383313  2015-10-07   morphiw0w        ExAequo      RIP Fonty       9752
# 383314  2015-10-07     overfly      RIP Fonty        ExAequo       7698
# 383315  2015-10-07     simozor      RIP Fonty        ExAequo       9753
# 383316  2015-10-07       xullE      RIP Fonty        ExAequo       9754
#
#         match_id  event_id  best_of  map_2  m2_kills  m2_assists  m2_deaths  \
# ...

# %%
map_2_df = map_2_df.dropna()

# %%
map_3_df = players_df[[
    'date',
    'player_name',
    'team',
    'opponent', 
    'player_id', 
    'match_id',
    'event_id',
    'best_of',
    'map_3',
    'm3_kills',
    'm3_assists',
    'm3_deaths',
    'm3_hs',
    'm3_flash_assists',
    'm3_kast',
    'm3_kddiff',
    'm3_adr',
    'm3_fkdiff',
    'm3_rating']].copy()
map_3_df
# Out:
#               date player_name           team       opponent  player_id  \
# 0       2020-02-26      Brehze  Evil Geniuses         Liquid       9136
# 1       2020-02-26        CeRq  Evil Geniuses         Liquid      11219
# 2       2020-02-26       EliGE         Liquid  Evil Geniuses       8738
# 3       2020-02-26       Ethan  Evil Geniuses         Liquid      10671
# 4       2020-02-26         NAF         Liquid  Evil Geniuses       8520
# ...            ...         ...            ...            ...        ...
# 383312  2015-10-07      kIMERA        ExAequo      RIP Fonty       7607
# 383313  2015-10-07   morphiw0w        ExAequo      RIP Fonty       9752
# 383314  2015-10-07     overfly      RIP Fonty        ExAequo       7698
# 383315  2015-10-07     simozor      RIP Fonty        ExAequo       9753
# 383316  2015-10-07       xullE      RIP Fonty        ExAequo       9754
#
#         match_id  event_id  best_of    map_3  m3_kills  m3_assists  m3_deaths  \
# ...

# %%
map_3_df = map_3_df.dropna()

# %%
map_3_df.columns
# Out:
# Index(['date', 'player_name', 'team', 'opponent', 'player_id', 'match_id',
#        'event_id', 'best_of', 'map_3', 'm3_kills', 'm3_assists', 'm3_deaths',
#        'm3_hs', 'm3_flash_assists', 'm3_kast', 'm3_kddiff', 'm3_adr',
#        'm3_fkdiff', 'm3_rating'],
#       dtype='object')

# %%
rename_column_headers = ['date',
    'player_name',
    'team', 
    'opponent',
    'player_id',
    'match_id',
    'event_id',
    'best_of',
    '_map',
    'kills',
    'assists',
    'deaths',
    'hs',
    'flash_assists',
    'kast',
    'kddiff',
    'adr',
    'fkdiff',
    'rating']

# Change column headers
map_1_df.columns = (rename_column_headers)
map_2_df.columns = (rename_column_headers)
map_3_df.columns = (rename_column_headers)

# %%
frames = [map_1_df, map_2_df, map_3_df]

revised_players = pd.concat(frames)

# %%
player_running_averages = revised_players.sort_values(['player_id','_map','date'])

# %%
player_running_averages
# Out:
#               date player_name           team         opponent  player_id  \
# 359523  2016-03-12       Friis             SK             FaZe          7
# 280188  2017-04-18       Friis        Tricked             SFTO          7
# 267010  2017-05-31       Friis        Tricked            PENTA          7
# 255059  2017-07-11       Friis  Gux & Friends  ALTERNATE aTTaX          7
# 255131  2017-07-11       Friis  Gux & Friends           Gambit          7
# ...            ...         ...            ...              ...        ...
# 737     2020-02-23      rabbit          Titan         Medieval      20006
# 722     2020-02-23     boskacz   Wisla Krakow              BIG      20007
# 115     2020-02-27       Porky            LND            Rysix      20009
# 119     2020-02-27       shevi            LND            Rysix      20010
# 153     2020-02-26      bichop        FREEROX        Sinisters      20011
#
#         match_id  event_id  best_of     _map  kills  assists  deaths    hs  \
# ...

# %%
players_revised = player_running_averages.loc[player_running_averages['deaths'] <= 30]
players_revised.describe()
# Out:
#            player_id      match_id       event_id        best_of  \
# count  442013.000000  4.420130e+05  442013.000000  442013.000000
# mean    10284.504374  2.324718e+06    3845.778697       2.423499
# std      4343.729831  9.367757e+03     751.313943       0.950582
# min         7.000000  2.300200e+06     820.000000       1.000000
# 25%      8321.000000  2.316941e+06    3219.000000       1.000000
# 50%     10394.000000  2.325125e+06    3808.000000       3.000000
# 75%     13232.000000  2.332785e+06    4484.000000       3.000000
# max     20011.000000  2.339828e+06    5233.000000       5.000000
#
#                kills        assists         deaths             hs  \
# count  442013.000000  442013.000000  442013.000000  442013.000000
# mean       17.745935       4.373781      17.720103       8.053729
# std         6.272111       2.493070       4.592555       3.840382
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
results_df = pd.read_csv('results.csv')

# %%
results_df
# Out:
#              date               team_1          team_2         _map  result_1  \
# 0      2020-03-18              Recon 5         TeamOne        Dust2         0
# 1      2020-03-18              Recon 5         TeamOne      Inferno        13
# 2      2020-03-18  New England Whalers        Station7      Inferno        12
# 3      2020-03-18              Rugratz  Bad News Bears      Inferno         7
# 4      2020-03-18              Rugratz  Bad News Bears      Vertigo         8
# ...           ...                  ...             ...          ...       ...
# 45768  2015-11-05                   G2      E-frag.net      Inferno        13
# 45769  2015-11-05                   G2      E-frag.net        Dust2        16
# 45770  2015-11-04                  CLG          Liquid      Inferno        16
# 45771  2015-11-03                  NiP        Dignitas        Train        16
# 45772  2015-11-03                  NiP            Envy  Cobblestone        16
#
# ...

# %%
result_rounds = results_df[['result_1','result_2']].copy()

result_rounds.describe()
# Out:
#            result_1      result_2
# count  45773.000000  45773.000000
# mean      13.385489     12.731545
# std        4.417713      4.715722
# min        0.000000      0.000000
# 25%       11.000000      9.000000
# 50%       16.000000     16.000000
# 75%       16.000000     16.000000
# max       38.000000     41.000000

# %%
# Only match results that didnt end in overtime(more than 30 rounds)

cleaned_results = results_df.loc[(results_df['result_1'] <= 16) & (results_df['result_2'] <= 16)]

# %%
# Created Total Rounds for each map
total_rounds = cleaned_results['result_1'] + cleaned_results['result_2']
cleaned_results['total_rounds'] = total_rounds
# Out:
# C:\Users\mferr\Anaconda\envs\mlenv\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
cleaned_results.columns
# Out:
# Index(['date', 'team_1', 'team_2', '_map', 'result_1', 'result_2',
#        'map_winner', 'starting_ct', 'ct_1', 't_2', 't_1', 'ct_2', 'event_id',
#        'match_id', 'rank_1', 'rank_2', 'map_wins_1', 'map_wins_2',
#        'match_winner', 'total_rounds'],
#       dtype='object')

# %%
cleaned_results = cleaned_results[['date', 'team_1', 'team_2', '_map',
       'map_winner',
       'match_id', 'total_rounds']].copy()

# %%
cleaned_results
# Out:
#              date               team_1          team_2         _map  \
# 0      2020-03-18              Recon 5         TeamOne        Dust2
# 1      2020-03-18              Recon 5         TeamOne      Inferno
# 2      2020-03-18  New England Whalers        Station7      Inferno
# 3      2020-03-18              Rugratz  Bad News Bears      Inferno
# 4      2020-03-18              Rugratz  Bad News Bears      Vertigo
# ...           ...                  ...             ...          ...
# 45768  2015-11-05                   G2      E-frag.net      Inferno
# 45769  2015-11-05                   G2      E-frag.net        Dust2
# 45770  2015-11-04                  CLG          Liquid      Inferno
# 45771  2015-11-03                  NiP        Dignitas        Train
# 45772  2015-11-03                  NiP            Envy  Cobblestone
#
#        map_winner  match_id  total_rounds
# 0               2   2340454            16
# 1               2   2340454            29
# ...

# %%
# Seperating Results by team
team_1_results = cleaned_results[['date', 'team_1', '_map',
                                  'map_winner','match_id', 'total_rounds']].copy()

team_2_results = cleaned_results[['date', 'team_2', '_map',
                                  'map_winner','match_id', 'total_rounds']].copy()

# %%
# New result team headers
team_headers = ['date', 'team', '_map', 'map_winner','match_id', 'total_rounds']

# %%
# Chnaging the map_winner value from 1 or 2 to W or L
team_2_results.loc[team_2_results.map_winner == 2, 'map_winner'] = 'W'
team_2_results.loc[team_2_results.map_winner == 1, 'map_winner'] = 'L'

team_1_results.loc[team_1_results.map_winner == 2, 'map_winner'] = 'L'
team_1_results.loc[team_1_results.map_winner == 1, 'map_winner'] = 'W'

# %%
# Renaming team columns
team_1_results.columns = team_headers
team_2_results.columns = team_headers

# %%
team_cleaned_results = pd.concat([team_1_results,team_2_results])

# %%
team_cleaned_results
# Out:
#              date                 team         _map map_winner  match_id  \
# 0      2020-03-18              Recon 5        Dust2          L   2340454
# 1      2020-03-18              Recon 5      Inferno          L   2340454
# 2      2020-03-18  New England Whalers      Inferno          L   2340461
# 3      2020-03-18              Rugratz      Inferno          L   2340453
# 4      2020-03-18              Rugratz      Vertigo          L   2340453
# ...           ...                  ...          ...        ...       ...
# 45768  2015-11-05           E-frag.net      Inferno          W   2299059
# 45769  2015-11-05           E-frag.net        Dust2          L   2299059
# 45770  2015-11-04               Liquid      Inferno          L   2299011
# 45771  2015-11-03             Dignitas        Train          L   2299001
# 45772  2015-11-03                 Envy  Cobblestone          L   2299003
#
#        total_rounds
# 0                16
# 1                29
# 2                28
# ...

# %%
player_results_rev = pd.merge(players_revised, cleaned_results, on=['match_id','_map','date'])

# %%
# Averages for player performances (There are outliers in the dataset)
player_results_rev.describe()
# Out:
#            player_id      match_id       event_id        best_of  \
# count  287611.000000  2.876110e+05  287611.000000  287611.000000
# mean     9756.000671  2.325372e+06    3877.733000       2.377809
# std      4158.912515  8.858888e+03     717.096229       0.939331
# min         7.000000  2.308279e+06     820.000000       1.000000
# 25%      7996.000000  2.317840e+06    3301.000000       1.000000
# 50%      9660.000000  2.325667e+06    3858.000000       3.000000
# 75%     12553.000000  2.333080e+06    4484.000000       3.000000
# max     20007.000000  2.339828e+06    5225.000000       5.000000
#
#                kills        assists         deaths             hs  \
# count  287611.000000  287611.000000  287611.000000  287611.000000
# mean       16.906457       4.225923      16.930886       7.741390
# std         5.616812       2.399321       3.956178       3.625564
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
# Creating New features based on player statistics and rounds played

# %%
KPR = player_results_rev['kills']/ player_results_rev['total_rounds']
player_results_rev['KPR'] = KPR

# %%
SPR = (player_results_rev['total_rounds'] - player_results_rev['deaths'])/player_results_rev['total_rounds']
player_results_rev['SPR'] = SPR

# %%
DPR = player_results_rev['deaths']/player_results_rev['total_rounds']
player_results_rev['DPR'] = DPR

# %%
APR = player_results_rev['assists']/player_results_rev['total_rounds']
player_results_rev['APR'] = APR

# %%
organised_player_results = player_results_rev.sort_values(by=['player_id','date'])
organised_player_results
# Out:
#               date player_name          team     opponent  player_id  \
# 160     2017-04-02       Friis       Tricked         LDLC          7
# 290     2017-04-02       Friis       Tricked  HellRaisers          7
# 570     2017-04-02       Friis       Tricked       ENCORE          7
# 400     2017-04-03       Friis       Tricked     FlipSid3          7
# 300     2017-04-04       Friis       Tricked        PRIDE          7
# ...            ...         ...           ...          ...        ...
# 151250  2020-02-19       endly       kinetic          AGF      19994
# 151290  2020-02-19       endly       kinetic          AGF      19994
# 151396  2020-02-19       endly       kinetic          AGF      19994
# 287570  2020-02-20  GeT_FuCkEd         Esper      TRIDENT      19995
# 92524   2020-02-23     boskacz  Wisla Krakow          BIG      20007
#
#         match_id  event_id  best_of     _map  kills  ...  fkdiff  rating  \
# ...

# %%
# Establishing player averages to build player ratings off of
Average_KPR = organised_player_results.groupby(['player_id']).KPR.apply(lambda x : x.expanding(min_periods=1).mean().fillna(x))
Average_KPR
# Out:
# 160       0.791667
# 290       0.575833
# 570       0.717222
# 400       0.696250
# 300       0.675182
#             ...
# 151250    0.666667
# 151290    0.522989
# 151396    0.507389
# 287570    0.555556
# 92524     0.166667
# Name: KPR, Length: 287611, dtype: float64

# %%
organised_player_results.loc[:,'Average_KPR'] = Average_KPR

# %%
Average_SPR = organised_player_results.groupby(['player_id']).SPR.apply(lambda x : x.expanding(min_periods=1).mean().fillna(x))
Average_SPR
# Out:
# 160       0.583333
# 290       0.411667
# 570       0.441111
# 400       0.405833
# 300       0.370121
#             ...
# 151250    0.400000
# 151290    0.320690
# 151396    0.293158
# 287570    0.148148
# 92524     0.111111
# Name: SPR, Length: 287611, dtype: float64

# %%
organised_player_results.loc[:,'Average_SPR'] = Average_SPR

# %%
Average_DPR = organised_player_results.groupby(['player_id']).DPR.apply(lambda x : x.expanding(min_periods=1).mean().fillna(x))
Average_DPR
# Out:
# 160       0.416667
# 290       0.588333
# 570       0.558889
# 400       0.594167
# 300       0.629879
#             ...
# 151250    0.600000
# 151290    0.679310
# 151396    0.706842
# 287570    0.851852
# 92524     0.888889
# Name: DPR, Length: 287611, dtype: float64

# %%
organised_player_results.loc[:,'Average_DPR'] = Average_DPR

# %%
Average_APR = organised_player_results.groupby(['player_id']).APR.apply(lambda x : x.expanding(min_periods=1).mean().fillna(x))
Average_APR
# Out:
# 160       0.166667
# 290       0.123333
# 570       0.193333
# 400       0.153333
# 300       0.140848
#             ...
# 151250    0.100000
# 151290    0.101724
# 151396    0.067816
# 287570    0.185185
# 92524     0.055556
# Name: APR, Length: 287611, dtype: float64

# %%
organised_player_results.loc[:,'Average_APR'] = Average_APR

# %%
Average_KAST = organised_player_results.groupby(['player_id']).kast.apply(lambda x : x.expanding(min_periods=1).mean().fillna(x))
Average_KAST
# Out:
# 160       83.300000
# 290       63.650000
# 570       72.066667
# 400       68.225000
# 300       64.580000
#             ...
# 151250    66.700000
# 151290    62.650000
# 151396    57.633333
# 287570    59.300000
# 92524     22.200000
# Name: kast, Length: 287611, dtype: float64

# %%
organised_player_results.loc[:,'Average_KAST'] = Average_KAST

# %%
Average_ADR = organised_player_results.groupby(['player_id']).adr.apply(lambda x : x.expanding(min_periods=1).mean().fillna(x))
Average_ADR
# Out:
# 160       83.400000
# 290       60.850000
# 570       73.166667
# 400       69.775000
# 300       69.280000
#             ...
# 151250    65.200000
# 151290    59.350000
# 151396    57.400000
# 287570    70.500000
# 92524     19.700000
# Name: adr, Length: 287611, dtype: float64

# %%
organised_player_results.loc[:,'Average_ADR'] = Average_ADR

# %%
# Building player stat ratings per map
KPR_rating = organised_player_results['KPR']/organised_player_results['Average_KPR']
KPR_rating
# Out:
# 160       1.000000
# 290       0.625181
# 570       1.394268
# 400       0.909635
# 300       0.875185
#             ...
# 151250    1.000000
# 151290    0.725275
# 151396    0.938511
# 287570    1.000000
# 92524     1.000000
# Length: 287611, dtype: float64

# %%
organised_player_results.loc[:,'KPR_rating'] = KPR_rating

# %%
DPR_rating = organised_player_results['DPR']/organised_player_results['Average_DPR']
DPR_rating
# Out:
# 160       1.000000
# 290       1.291785
# 570       0.894632
# 400       1.178121
# 300       1.226787
#             ...
# 151250    1.000000
# 151290    1.116751
# 151396    1.077900
# 287570    1.000000
# 92524     1.000000
# Length: 287611, dtype: float64

# %%
organised_player_results.loc[:,'DPR_rating'] = DPR_rating

# %%
SPR_rating = organised_player_results['SPR']/organised_player_results['Average_SPR']
SPR_rating
# Out:
# 160       1.000000
# 290       0.582996
# 570       1.133501
# 400       0.739220
# 300       0.614049
#             ...
# 151250    1.000000
# 151290    0.752688
# 151396    0.812173
# 287570    1.000000
# 92524     1.000000
# Length: 287611, dtype: float64

# %%
organised_player_results.loc[:,'SPR_rating'] = SPR_rating

# %%
APR_rating = organised_player_results['APR']/organised_player_results['Average_APR']
APR_rating
# Out:
# 160       1.000000
# 290       0.648649
# 570       1.724138
# 400       0.217391
# 300       0.645439
#             ...
# 151250    1.000000
# 151290    1.016949
# 151396    0.000000
# 287570    1.000000
# 92524     1.000000
# Length: 287611, dtype: float64

# %%
organised_player_results.loc[:,'APR_rating'] = APR_rating

# %%
KAST_rating = organised_player_results['kast']/organised_player_results['Average_KAST']
KAST_rating
# Out:
# 160       1.000000
# 290       0.691280
# 570       1.233580
# 400       0.831074
# 300       0.774234
#             ...
# 151250    1.000000
# 151290    0.935355
# 151396    0.825911
# 287570    1.000000
# 92524     1.000000
# Length: 287611, dtype: float64

# %%
organised_player_results.loc[:,'KAST_rating'] = KAST_rating

# %%
ADR_rating = organised_player_results['adr']/organised_player_results['Average_ADR']
ADR_rating
# Out:
# 160       1.000000
# 290       0.629417
# 570       1.336674
# 400       0.854174
# 300       0.971420
#             ...
# 151250    1.000000
# 151290    0.901432
# 151396    0.932056
# 287570    1.000000
# 92524     1.000000
# Length: 287611, dtype: float64

# %%
organised_player_results.loc[:,'ADR_rating'] = ADR_rating

# %%
pd.set_option('max_columns', None)
organised_player_results
# Out:
#               date player_name          team     opponent  player_id  \
# 160     2017-04-02       Friis       Tricked         LDLC          7
# 290     2017-04-02       Friis       Tricked  HellRaisers          7
# 570     2017-04-02       Friis       Tricked       ENCORE          7
# 400     2017-04-03       Friis       Tricked     FlipSid3          7
# 300     2017-04-04       Friis       Tricked        PRIDE          7
# ...            ...         ...           ...          ...        ...
# 151250  2020-02-19       endly       kinetic          AGF      19994
# 151290  2020-02-19       endly       kinetic          AGF      19994
# 151396  2020-02-19       endly       kinetic          AGF      19994
# 287570  2020-02-20  GeT_FuCkEd         Esper      TRIDENT      19995
# 92524   2020-02-23     boskacz  Wisla Krakow          BIG      20007
#
#         match_id  event_id  best_of     _map  kills  assists  deaths   hs  \
# ...

# %%
pd.set_option('display.max_columns', None)
organised_player_results.describe()
# Out:
#            player_id      match_id       event_id        best_of  \
# count  287611.000000  2.876110e+05  287611.000000  287611.000000
# mean     9756.000671  2.325372e+06    3877.733000       2.377809
# std      4158.912515  8.858888e+03     717.096229       0.939331
# min         7.000000  2.308279e+06     820.000000       1.000000
# 25%      7996.000000  2.317840e+06    3301.000000       1.000000
# 50%      9660.000000  2.325667e+06    3858.000000       3.000000
# 75%     12553.000000  2.333080e+06    4484.000000       3.000000
# max     20007.000000  2.339828e+06    5225.000000       5.000000
#
#                kills        assists         deaths             hs  \
# count  287611.000000  287611.000000  287611.000000  287611.000000
# mean       16.906457       4.225923      16.930886       7.741390
# std         5.616812       2.399321       3.956178       3.625564
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
# attempted to create a better baseline for each player to build their ratings

baseline_averages = organised_player_results.drop_duplicates(['player_id']).groupby('player_id').head(1)

# %%
baseline_averages.columns
# Out:
# Index(['date', 'player_name', 'team', 'opponent', 'player_id', 'match_id',
#        'event_id', 'best_of', '_map', 'kills', 'assists', 'deaths', 'hs',
#        'flash_assists', 'kast', 'kddiff', 'adr', 'fkdiff', 'rating', 'team_1',
#        'team_2', 'map_winner', 'total_rounds', 'KPR', 'SPR', 'DPR', 'APR',
#        'Average_KPR', 'Average_SPR', 'Average_DPR', 'Average_APR',
#        'Average_KAST', 'Average_ADR', 'KPR_rating', 'DPR_rating', 'SPR_rating',
#        'APR_rating', 'KAST_rating', 'ADR_rating'],
#       dtype='object')

# %%
baseline_averages.loc[:,'Average_KPR'] = .67
baseline_averages.loc[:,'Average_SPR'] = .32
baseline_averages.loc[:,'Average_DPR'] = .67
baseline_averages.loc[:,'Average_APR'] = .16
baseline_averages.loc[:,'Average_ADR'] = 74.3
baseline_averages.loc[:,'Average_KAST'] = 69.34

# %%
baseline_averages
# Out:
#               date    player_name             team   opponent  player_id  \
# 160     2017-04-02          Friis          Tricked       LDLC          7
# 690     2018-11-25         RashiE         Kingpins  Nordavind         13
# 730     2017-05-21         m1kkis           Tundra    GODSENT         15
# 770     2017-07-09          Zyppe           Crowns    Kinguin         17
# 850     2017-11-14          zonic         Astralis        NiP         21
# ...            ...            ...              ...        ...        ...
# 267442  2020-02-23          ryota          Updraft     ikarus      19986
# 205076  2020-02-17  AsLanMashadoW  Demolition Crew     pro100      19988
# 151250  2020-02-19          endly          kinetic        AGF      19994
# 287570  2020-02-20     GeT_FuCkEd            Esper    TRIDENT      19995
# 92524   2020-02-23        boskacz     Wisla Krakow        BIG      20007
#
#         match_id  event_id  best_of         _map  kills  assists  deaths  \
# ...

# %%
baseline_averages = baseline_averages[['player_id','match_id','_map','Average_KPR','Average_SPR','Average_DPR','Average_APR','Average_ADR','Average_KAST']]

# %%
baseline_averages
# Out:
#         player_id  match_id         _map  Average_KPR  Average_SPR  \
# 160             7   2309309      Inferno         0.67         0.32
# 690            13   2329416       Mirage         0.67         0.32
# 730            15   2310992       Mirage         0.67         0.32
# 770            17   2312531  Cobblestone         0.67         0.32
# 850            21   2317263     Overpass         0.67         0.32
# ...           ...       ...          ...          ...          ...
# 267442      19986   2339739         Nuke         0.67         0.32
# 205076      19988   2339630      Inferno         0.67         0.32
# 151250      19994   2339692      Inferno         0.67         0.32
# 287570      19995   2339711       Mirage         0.67         0.32
# 92524       20007   2339745         Nuke         0.67         0.32
#
#         Average_DPR  Average_APR  Average_ADR  Average_KAST
# 160            0.67         0.16         74.3          0.69
# ...

# %%
organised_player_results.update(baseline_averages)

# %%
organised_player_results
# Out:
#               date player_name          team     opponent  player_id  \
# 160     2017-04-02       Friis       Tricked         LDLC        7.0
# 290     2017-04-02       Friis       Tricked  HellRaisers        7.0
# 570     2017-04-02       Friis       Tricked       ENCORE        7.0
# 400     2017-04-03       Friis       Tricked     FlipSid3        7.0
# 300     2017-04-04       Friis       Tricked        PRIDE        7.0
# ...            ...         ...           ...          ...        ...
# 151250  2020-02-19       endly       kinetic          AGF    19994.0
# 151290  2020-02-19       endly       kinetic          AGF    19994.0
# 151396  2020-02-19       endly       kinetic          AGF    19994.0
# 287570  2020-02-20  GeT_FuCkEd         Esper      TRIDENT    19995.0
# 92524   2020-02-23     boskacz  Wisla Krakow          BIG    20007.0
#
#          match_id  event_id  best_of     _map  kills  assists  deaths   hs  \
# ...

# %%
player_rating = (organised_player_results['KPR_rating']+organised_player_results['DPR_rating']+organised_player_results['SPR_rating']+organised_player_results['APR_rating']+organised_player_results['KAST_rating']+organised_player_results['ADR_rating'])/4.8
organised_player_results['custom_rating'] = player_rating

# %%
organised_player_results.sort_values(by=['match_id','team'])
# Out:
#               date player_name      team  opponent  player_id  match_id  \
# 250211  2017-04-03        urbz  Corvidae    Legacy       9103   2308279
# 250212  2017-04-03        DANZ  Corvidae    Legacy       9104   2308279
# 250216  2017-04-03        dash  Corvidae    Legacy      11793   2308279
# 250217  2017-04-03     RequieM  Corvidae    Legacy      11974   2308279
# 250218  2017-04-03       m1tch  Corvidae    Legacy      11975   2308279
# ...            ...         ...       ...       ...        ...       ...
# 283602  2020-02-26       Jinxx    Chiefs  Airborne      11538   2339828
# 283604  2020-02-26        stat    Chiefs  Airborne      12086   2339828
# 283605  2020-02-26     apocdud    Chiefs  Airborne      12872   2339828
# 283607  2020-02-26       SkulL    Chiefs  Airborne      14290   2339828
# 283608  2020-02-26      Mayker    Chiefs  Airborne      14957   2339828
#
#         event_id  best_of     _map  kills  assists  deaths    hs  \
# ...

# %%
pd.reset_option('display.max_rows', None)
not_full_matches = organised_player_results[(organised_player_results['match_id'].map(organised_player_results['match_id'].value_counts()) % 5 != 0) & (organised_player_results['_map'].map(organised_player_results['_map'].value_counts()) % 5 != 0)]

# %%
not_full_matches.sort_values(by=['match_id','team']).head(50)
# Out:
#               date player_name           team       opponent  player_id  \
# 188028  2017-04-07        exit  Black Dragons          TShow      11154
# 188031  2017-04-07          YJ  Black Dragons          TShow      11746
# 188032  2017-04-07         jnt  Black Dragons          TShow      11747
# 188033  2017-04-07       raafa  Black Dragons          TShow      11748
# 188026  2017-04-07      guerri          TShow  Black Dragons       6547
# 188027  2017-04-07      knight          TShow  Black Dragons      10559
# 188029  2017-04-07         f11          TShow  Black Dragons      11331
# 188030  2017-04-07         zam          TShow  Black Dragons      11333
# 188034  2017-04-07        VINI          TShow  Black Dragons      12822
# 62169   2017-04-10       crush            ACG            EPG       9348
# 62170   2017-04-10         def            ACG            EPG       9350
# 62171   2017-04-10       novel            ACG            EPG      10604
# ...

# %%
df = pd.merge(organised_player_results,not_full_matches, how='outer', indicator=True)

# %%
full_player_games = df.loc[df._merge == 'left_only']

# %%
full_player_games.sort_values(by=['match_id','team']).head(10)
# Out:
#               date player_name      team  opponent  player_id  match_id  \
# 119989  2017-04-03        urbz  Corvidae    Legacy       9103   2308279
# 120201  2017-04-03        DANZ  Corvidae    Legacy       9104   2308279
# 198282  2017-04-03        dash  Corvidae    Legacy      11793   2308279
# 204763  2017-04-03     RequieM  Corvidae    Legacy      11974   2308279
# 204765  2017-04-03       m1tch  Corvidae    Legacy      11975   2308279
# 105003  2017-04-03   dizzyLife    Legacy  Corvidae       8766   2308279
# 121726  2017-04-03     deoxiDE    Legacy  Corvidae       9117   2308279
# 121872  2017-04-03      spiKez    Legacy  Corvidae       9120   2308279
# 189796  2017-04-03        gotz    Legacy  Corvidae      11483   2308279
# 227155  2017-04-03      mattcd    Legacy  Corvidae      13058   2308279
#
#         event_id  best_of   _map  kills  assists  deaths    hs  flash_assists  \
# 119989      2674        1  Cache   22.0      5.0    21.0  13.0            2.0
# ...

# %%
full_player_games.columns
# Out:
# Index(['date', 'player_name', 'team', 'opponent', 'player_id', 'match_id',
#        'event_id', 'best_of', '_map', 'kills', 'assists', 'deaths', 'hs',
#        'flash_assists', 'kast', 'kddiff', 'adr', 'fkdiff', 'rating', 'team_1',
#        'team_2', 'map_winner', 'total_rounds', 'KPR', 'SPR', 'DPR', 'APR',
#        'Average_KPR', 'Average_SPR', 'Average_DPR', 'Average_APR',
#        'Average_KAST', 'Average_ADR', 'KPR_rating', 'DPR_rating', 'SPR_rating',
#        'APR_rating', 'KAST_rating', 'ADR_rating', 'custom_rating', '_merge'],
#       dtype='object')

# %%
full_player_games_rev = full_player_games[['date', 'player_name', 'team', 'opponent', 'player_id', 'match_id',
       'event_id', 'best_of', '_map', 'kills', 'assists', 'deaths', 'hs',
       'flash_assists', 'kast', 'kddiff', 'adr', 'fkdiff', 'rating','total_rounds', 'KPR', 'SPR', 'DPR', 'APR',
       'Average_KPR', 'Average_SPR', 'Average_DPR', 'Average_APR',
       'Average_KAST', 'Average_ADR', 'KPR_rating', 'DPR_rating', 'SPR_rating',
       'APR_rating', 'KAST_rating', 'ADR_rating', 'custom_rating']]

# %%
full_player_games_rev
# Out:
#               date player_name          team     opponent  player_id  \
# 0       2017-04-02       Friis       Tricked         LDLC          7
# 1       2017-04-02       Friis       Tricked  HellRaisers          7
# 2       2017-04-02       Friis       Tricked       ENCORE          7
# 3       2017-04-03       Friis       Tricked     FlipSid3          7
# 4       2017-04-04       Friis       Tricked        PRIDE          7
# ...            ...         ...           ...          ...        ...
# 287606  2020-02-19       endly       kinetic          AGF      19994
# 287607  2020-02-19       endly       kinetic          AGF      19994
# 287608  2020-02-19       endly       kinetic          AGF      19994
# 287609  2020-02-20  GeT_FuCkEd         Esper      TRIDENT      19995
# 287610  2020-02-23     boskacz  Wisla Krakow          BIG      20007
#
#         match_id  event_id  best_of     _map  kills  assists  deaths   hs  \
# ...

# %%
wins = {'kills': 'sum',
        'assists': 'sum',
        'deaths': 'sum',
        'kast': 'mean',
        'adr': 'mean',
        'KPR':'mean',
        'SPR':'mean',
        'DPR':'mean',
        'APR':'mean',
        'total_rounds':'mean',
        'Average_KPR': 'mean',
        'Average_DPR': 'mean',
        'Average_SPR': 'mean',
        'Average_APR': 'mean',
        'Average_KAST': 'mean',
        'Average_ADR': 'mean',
        'KPR_rating': 'mean',
        'DPR_rating': 'mean',
        'SPR_rating': 'mean',
        'APR_rating': 'mean',
        'KAST_rating': 'mean',
        'ADR_rating': 'mean',
    'custom_rating': 'mean'}
full_player_games_rev = full_player_games_rev.groupby(['match_id', 'team','opponent', '_map','date']).agg(wins)
full_player_games_rev
# Out:
#                                                          kills  assists  \
# match_id team          opponent     _map     date
# 2308279  Corvidae      Legacy       Cache    2017-04-03   98.0     21.0
#          Legacy        Corvidae     Cache    2017-04-03  110.0     25.0
# 2308283  Alpha Sydney  Athletico    Mirage   2017-04-06  100.0     25.0
#          Athletico     Alpha Sydney Mirage   2017-04-06   96.0     16.0
# 2308284  Alpha Sydney  Athletico    Inferno  2017-04-06   83.0     27.0
# ...                                                        ...      ...
# 2339816  Thunder Logic Station7     Overpass 2020-02-27   85.0     18.0
# 2339817  Divine        Oceanus      Dust2    2020-02-27  101.0     37.0
#          Oceanus       Divine       Dust2    2020-02-27   88.0     25.0
# 2339828  Airborne      Chiefs       Inferno  2020-02-26   66.0     10.0
#          Chiefs        Airborne     Inferno  2020-02-26   94.0     30.0
#
# ...

# %%
fpgr = pd.DataFrame(full_player_games_rev)

# %%
fpgr = fpgr.reset_index()

# %%
fpgr
# Out:
#        match_id           team      opponent      _map        date  kills  \
# 0       2308279       Corvidae        Legacy     Cache  2017-04-03   98.0
# 1       2308279         Legacy      Corvidae     Cache  2017-04-03  110.0
# 2       2308283   Alpha Sydney     Athletico    Mirage  2017-04-06  100.0
# 3       2308283      Athletico  Alpha Sydney    Mirage  2017-04-06   96.0
# 4       2308284   Alpha Sydney     Athletico   Inferno  2017-04-06   83.0
# ...         ...            ...           ...       ...         ...    ...
# 57149   2339816  Thunder Logic      Station7  Overpass  2020-02-27   85.0
# 57150   2339817         Divine       Oceanus     Dust2  2020-02-27  101.0
# 57151   2339817        Oceanus        Divine     Dust2  2020-02-27   88.0
# 57152   2339828       Airborne        Chiefs   Inferno  2020-02-26   66.0
# 57153   2339828         Chiefs      Airborne   Inferno  2020-02-26   94.0
#
#        assists  deaths   kast    adr       KPR       SPR       DPR       APR  \
# ...

# %%
fpgr.columns
# Out:
# Index(['match_id', 'team', 'opponent', '_map', 'date', 'kills', 'assists',
#        'deaths', 'kast', 'adr', 'total_rounds', 'Average_KPR', 'Average_DPR',
#        'Average_SPR', 'Average_APR', 'Average_KAST', 'Average_ADR',
#        'KPR_rating', 'DPR_rating', 'SPR_rating', 'APR_rating', 'KAST_rating',
#        'ADR_rating', 'custom_rating'],
#       dtype='object')

# %%
attempt_2 = fpgr[['match_id', 'team', 'opponent', '_map', 'date', 'KPR_rating',
       'DPR_rating', 'SPR_rating', 'APR_rating', 'KAST_rating', 'ADR_rating',
       'custom_rating']]
head = ['match_id', 'team', 'opponent', 'map', 'date', 'KPR_rating',
       'DPR_rating', 'SPR_rating', 'APR_rating', 'KAST_rating', 'ADR_rating',
       'custom_rating']
attempt_2.columns = head

# %%
attempt_team = pd.merge(attempt_2, revisedResults_df, on=['date','match_id','map'])
attempt_team
# Out:
#         match_id           team      opponent       map        date  \
# 0      2308279.0       Corvidae        Legacy     Cache  2017-04-03
# 1      2308279.0         Legacy      Corvidae     Cache  2017-04-03
# 2      2308283.0   Alpha Sydney     Athletico    Mirage  2017-04-06
# 3      2308283.0      Athletico  Alpha Sydney    Mirage  2017-04-06
# 4      2308284.0   Alpha Sydney     Athletico   Inferno  2017-04-06
# ...          ...            ...           ...       ...         ...
# 57149  2339816.0  Thunder Logic      Station7  Overpass  2020-02-27
# 57150  2339817.0         Divine       Oceanus     Dust2  2020-02-27
# 57151  2339817.0        Oceanus        Divine     Dust2  2020-02-27
# 57152  2339828.0       Airborne        Chiefs   Inferno  2020-02-26
# 57153  2339828.0         Chiefs      Airborne   Inferno  2020-02-26
#
#        KPR_rating  DPR_rating  SPR_rating  APR_rating  KAST_rating  \
# 0        1.008749    1.142563    0.732759    0.905172     0.955004
# ...

# %%
team_1 = fpgr.loc[1::2,:]
team_1
# Out:
#        match_id           team      opponent      _map        date  kills  \
# 1       2308279         Legacy      Corvidae     Cache  2017-04-03  110.0
# 3       2308283      Athletico  Alpha Sydney    Mirage  2017-04-06   96.0
# 5       2308284      Athletico  Alpha Sydney   Inferno  2017-04-06   94.0
# 7       2308285         Cypher      Corvidae    Mirage  2017-04-13   94.0
# 9       2308289  Funky Monkeys  Alpha Sydney     Train  2017-04-13   88.0
# ...         ...            ...           ...       ...         ...    ...
# 57145   2339814        Rugratz       Recon 5      Nuke  2020-02-27   71.0
# 57147   2339815       Under 21         Chaos      Nuke  2020-02-27   92.0
# 57149   2339816  Thunder Logic      Station7  Overpass  2020-02-27   85.0
# 57151   2339817        Oceanus        Divine     Dust2  2020-02-27   88.0
# 57153   2339828         Chiefs      Airborne   Inferno  2020-02-26   94.0
#
#        assists  deaths   kast    adr       KPR       SPR       DPR       APR  \
# ...

# %%
team_2 = fpgr.loc[::2,:]
team_2.sort_values(by=['team','date'])
# Out:
#        match_id         team  opponent         _map        date  kills  \
# 52012   2337450  100 Thieves      ENCE      Inferno  2019-11-07   81.0
# 52022   2337454  100 Thieves  Astralis      Inferno  2019-11-07   60.0
# 52038   2337458  100 Thieves      ENCE         Nuke  2019-11-08   81.0
# 52042   2337460  100 Thieves  Vitality         Nuke  2019-11-09  115.0
# 52046   2337462  100 Thieves  Astralis         Nuke  2019-11-10   54.0
# ...         ...          ...       ...          ...         ...    ...
# 1954    2310436          xTc    Energy      Inferno  2017-05-06   91.0
# 28096   2325455          xTc     Big 5        Cache  2018-08-09  105.0
# 2714    2310857      zARLANS    pro100        Cache  2017-05-16   58.0
# 2798    2310891      zARLANS       LOG      Inferno  2017-05-18   91.0
# 1156    2310011          zzz   Outlaws  Cobblestone  2017-04-23   86.0
#
#        assists  deaths   kast    adr       KPR       SPR       DPR       APR  \
# ...

# %%
team_1.columns
# Out:
# Index(['match_id', 'team', 'opponent', '_map', 'date', 'kills', 'assists',
#        'deaths', 'kast', 'adr', 'KPR', 'SPR', 'DPR', 'APR', 'total_rounds',
#        'Average_KPR', 'Average_DPR', 'Average_SPR', 'Average_APR',
#        'Average_KAST', 'Average_ADR', 'KPR_rating', 'DPR_rating', 'SPR_rating',
#        'APR_rating', 'KAST_rating', 'ADR_rating', 'custom_rating'],
#       dtype='object')

# %%
team_1_headers = ['match_id','team_1','map','date', '1_kills', '1_assists',
       '1_deaths', '1_kast', '1_adr','1_KPR','1_SPR','1_DPR','1_APR','1_total_rounds', '1_Average_KPR', '1_Average_DPR',
       '1_Average_SPR', '1_Average_APR', '1_Average_KAST', '1_Average_ADR','1_KPR_rating',
       '1_DPR_rating', '1_SPR_rating', '1_APR_rating', '1_KAST_rating', '1_ADR_rating','1_custom_rating']
team_2_headers = ['match_id','team_2','map','date', '2_kills', '2_assists',
       '2_deaths', '2_kast', '2_adr','2_KPR','2_SPR','2_DPR','2_APR', '2_total_rounds', '2_Average_KPR', '2_Average_DPR',
       '2_Average_SPR', '2_Average_APR', '2_Average_KAST', '2_Average_ADR','2_KPR_rating',
       '2_DPR_rating', '2_SPR_rating', '2_APR_rating', '2_KAST_rating', '2_ADR_rating','2_custom_rating']

team_1 = team_1[['match_id', 'team', '_map', 'date', 'kills', 'assists',
       'deaths', 'kast', 'adr','KPR','SPR','DPR','APR', 'total_rounds', 'Average_KPR', 'Average_DPR',
       'Average_SPR', 'Average_APR', 'Average_KAST', 'Average_ADR',
       'KPR_rating', 'DPR_rating', 'SPR_rating', 'APR_rating', 'KAST_rating',
       'ADR_rating', 'custom_rating']]
team_2 = team_2[['match_id', 'team', '_map', 'date', 'kills', 'assists',
       'deaths', 'kast', 'adr','KPR','SPR','DPR','APR', 'total_rounds', 'Average_KPR', 'Average_DPR',
       'Average_SPR', 'Average_APR', 'Average_KAST', 'Average_ADR',
       'KPR_rating', 'DPR_rating', 'SPR_rating', 'APR_rating', 'KAST_rating',
       'ADR_rating', 'custom_rating']]

team_1.columns = team_1_headers
team_2.columns = team_2_headers

# %%
team_1.columns
# Out:
# Index(['match_id', 'team', 'opponent', '_map', 'date', 'kills', 'assists',
#        'deaths', 'kast', 'adr', 'total_rounds', 'Average_KPR', 'Average_DPR',
#        'Average_SPR', 'Average_APR', 'Average_KAST', 'Average_ADR',
#        'custom_rating'],
#       dtype='object')

# %%
headers_practice = ['match_id', 'team', 'opponent', 'map', 'date', 'kills', 'assists',
       'deaths', 'kast', 'adr', 'total_rounds', 'Average_KPR', 'Average_DPR',
       'Average_SPR', 'Average_APR', 'Average_KAST', 'Average_ADR',
       'KPR_rating', 'DPR_rating', 'SPR_rating', 'APR_rating', 'KAST_rating',
       'ADR_rating', 'custom_rating']
team_1.columns = headers_practice
team_2.columns = headers_practice

# %%
prac_team_1 = pd.merge(team_1, revisedResults_df, on=['date','match_id','map'])
prac_team_2 = pd.merge(team_2, revisedResults_df, on=['date','match_id','map'])

prac_team_2.loc[prac_team_2.map_winner == 2, 'map_winner'] = 'W'
prac_team_2.loc[prac_team_2.map_winner == 1, 'map_winner'] = 'L'

prac_team_1.loc[prac_team_1.map_winner == 2, 'map_winner'] = 'L'
prac_team_1.loc[prac_team_1.map_winner == 1, 'map_winner'] = 'W'

# %%
prac_header = ['match_id', 'team','opponent','map', 'date', 'kills', 'assists',
       'deaths', 'kast', 'adr', 'total_rounds', 'Average_KPR', 'Average_DPR',
       'Average_SPR', 'Average_APR', 'Average_KAST', 'Average_ADR',
       'KPR_rating', 'DPR_rating', 'SPR_rating', 'APR_rating', 'KAST_rating',
       'ADR_rating', 'custom_rating','map_winner']

prac_team_1.columns = prac_header
prac_team_2.columns = prac_header

# %%
prac_team_1.sort_values(by=['date','team'])
# Out:
#         match_id           team   opponent          map        date  kills  \
# 6      2308382.0      Immortals       FaZe        Train  2017-03-01   10.8
# 7      2308384.0      Immortals   Astralis        Train  2017-03-01   16.4
# 51     2309187.0        Kinguin     Spirit      Inferno  2017-03-31   18.2
# 63     2309242.0          PENTA  iGame.com     Overpass  2017-03-31   19.2
# 52     2309187.0         Spirit    Kinguin  Cobblestone  2017-03-31   19.6
# ...          ...            ...        ...          ...         ...    ...
# 28550  2339766.0        Oceanus     Mythic      Vertigo  2020-02-27   13.2
# 28575  2339817.0        Oceanus     Divine        Dust2  2020-02-27   17.6
# 28572  2339814.0        Rugratz    Recon 5         Nuke  2020-02-27   14.2
# 28574  2339816.0  Thunder Logic   Station7     Overpass  2020-02-27   17.0
# 28573  2339815.0       Under 21      Chaos         Nuke  2020-02-27   18.4
#
# ...

# %%
prac_team_2.sort_values(by=['team','date']).head(20)
# Out:
#         match_id         team             opponent      map        date  \
# 26006  2337450.0  100 Thieves                 ENCE  Inferno  2019-11-07
# 26011  2337454.0  100 Thieves             Astralis  Inferno  2019-11-07
# 26019  2337458.0  100 Thieves                 ENCE     Nuke  2019-11-08
# 26021  2337460.0  100 Thieves             Vitality     Nuke  2019-11-09
# 26023  2337462.0  100 Thieves             Astralis     Nuke  2019-11-10
# 26024  2337462.0  100 Thieves             Astralis  Vertigo  2019-11-10
# 25932  2337376.0  100 Thieves              eUnited    Dust2  2019-11-17
# 25936  2337378.0  100 Thieves               Isurus  Inferno  2019-11-18
# 25938  2337379.0  100 Thieves                FURIA  Inferno  2019-11-19
# 26593  2338040.0  100 Thieves               Heroic  Vertigo  2019-12-03
# 26608  2338052.0  100 Thieves        Evil Geniuses   Mirage  2019-12-03
# 26626  2338059.0  100 Thieves                 FaZe    Dust2  2019-12-04
# ...

# %%
testing = pd.concat([prac_team_1,prac_team_2])
testing.to_csv('testing.csv')

# %%
testing.sort_values(by=['opponent','date'])
# Out:
#         match_id          team     opponent          map        date  kills  \
# 26006  2337450.0          ENCE  100 Thieves      Inferno  2019-11-07    8.8
# 26011  2337454.0      Astralis  100 Thieves      Inferno  2019-11-07   17.8
# 26019  2337458.0          ENCE  100 Thieves         Nuke  2019-11-08   14.0
# 26021  2337460.0      Vitality  100 Thieves         Nuke  2019-11-09   19.0
# 26024  2337462.0      Astralis  100 Thieves         Nuke  2019-11-10   15.8
# ...          ...           ...          ...          ...         ...    ...
# 576    2310011.0       Outlaws          zzz  Cobblestone  2017-04-23   20.6
# 570    2310005.0  dreamchasers          zzz         Nuke  2017-04-23   20.0
# 575    2310010.0           KPI          zzz     Overpass  2017-04-23   16.8
# 576    2310011.0       Outlaws          zzz        Cache  2017-04-23   15.4
# 577    2310011.0       Outlaws          zzz     Overpass  2017-04-23   19.0
#
# ...

# %%
combined_teams = pd.merge(team_1,team_2, on=['match_id','map','date'])

# %%
combined_teams.sort_values(by=['date','match_id'])
# Out:
#        match_id          team_1          map        date  1_kills  1_assists  \
# 6       2308382       Immortals        Train  2017-03-01     54.0        7.0
# 7       2308384       Immortals        Train  2017-03-01     82.0       20.0
# 44      2309186  fnatic Academy        Cache  2017-03-31     60.0       18.0
# 45      2309187         Kinguin      Inferno  2017-03-31     91.0       27.0
# 46      2309187          Spirit  Cobblestone  2017-03-31     98.0       28.0
# ...         ...             ...          ...         ...      ...        ...
# 17319   2339768          Mythic        Dust2  2020-02-27    100.0       36.0
# 17340   2339814         Rugratz         Nuke  2020-02-27     71.0       22.0
# 17341   2339815        Under 21         Nuke  2020-02-27     92.0       19.0
# 17342   2339816   Thunder Logic     Overpass  2020-02-27     85.0       18.0
# 17343   2339817         Oceanus        Dust2  2020-02-27     88.0       25.0
#
# ...

# %%
results = pd.read_csv('results.csv')

# %%
revisedResults_df = results[['date','match_id','_map','map_winner']]

# %%
revised_headers = ['date','match_id','map','map_winner']

# %%
revisedResults_df.columns = revised_headers

# %%
team_completed_df = pd.merge(combined_teams, revisedResults_df, on=['date','match_id','map'])

# %%
team_completed_df
# Out:
#        match_id         team_1       map        date  1_kills  1_assists  \
# 0       2308279         Legacy     Cache  2017-04-03    110.0       25.0
# 1       2308283      Athletico    Mirage  2017-04-06     96.0       16.0
# 2       2308284      Athletico   Inferno  2017-04-06     94.0       23.0
# 3       2308285         Cypher    Mirage  2017-04-13     94.0       23.0
# 4       2308289  Funky Monkeys     Train  2017-04-13     88.0       19.0
# ...         ...            ...       ...         ...      ...        ...
# 17340   2339814        Rugratz      Nuke  2020-02-27     71.0       22.0
# 17341   2339815       Under 21      Nuke  2020-02-27     92.0       19.0
# 17342   2339816  Thunder Logic  Overpass  2020-02-27     85.0       18.0
# 17343   2339817        Oceanus     Dust2  2020-02-27     88.0       25.0
# 17344   2339828         Chiefs   Inferno  2020-02-26     94.0       30.0
#
#        1_deaths  1_kast  1_adr     1_KPR     1_SPR     1_DPR     1_APR  \
# ...

# %%
team_completed_df.to_csv('team_completed_df.csv')

# %%
# Finding match ID's where there are not 5 total players for each team
pd.set_option('display.max_rows', None)
opponent_less_5['match_id'].value_counts()
# Out:
# 2325518.0    29
# 2327060.0    29
# 2330756.0    29
# 2338130.0    29
# 2321163.0    29
# 2313305.0    29
# 2315731.0    28
# 2338537.0    28
# 2326179.0    28
# 2318659.0    28
# 2336636.0    28
# 2329064.0    27
# 2322623.0    27
# 2315141.0    27
# 2322557.0    27
# 2330769.0    27
# 2314954.0    27
# 2336675.0    27
# 2329751.0    27
# 2335912.0    27
# 2327004.0    27
# 2333133.0    27
# 2315227.0    26
# 2335709.0    26
# 2335208.0    26
# 2315277.0    26
# 2315296.0    26
# 2318190.0    26
# 2330711.0    26
# 2334558.0    26
# 2333869.0    26
# 2338469.0    26
# 2332385.0    26
# 2338713.0    26
# 2310281.0    26
# 2332860.0    26
# 2328062.0    26
# 2313253.0    26
# 2335929.0    24
# 2330731.0    19
# 2326743.0    19
# 2332238.0    19
# 2335047.0    19
# 2325602.0    19
# 2319827.0    19
# 2315113.0    19
# 2336610.0    19
# 2320274.0    19
# 2312059.0    19
# 2312261.0    19
# 2313282.0    19
# 2330511.0    19
# 2338436.0    19
# 2325844.0    18
# 2335998.0    18
# ...
