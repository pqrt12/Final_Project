# %%
import pandas as pd
from config import password
from config import port
from config import host

# %%
players_df = pd.read_csv('players.csv')

# %%
map_1_df = players_df[[
    'date',
    'player_name',
    'team',
    'opponent', 
    'player_id', 
    'match_id',
    'event_id',
    'best_of',
    'map_1',
    'm1_kills',
    'm1_assists',
    'm1_deaths',
    'm1_hs',
    'm1_flash_assists',
    'm1_kast',
    'm1_kddiff',
    'm1_adr',
    'm1_fkdiff',
    'm1_rating']].copy()
map_1_df
# Out:
#               date player_name           team       opponent  player_id  \
# 0       2020-02-26      Brehze  Evil Geniuses         Liquid       9136
# 1       2020-02-26        CeRq  Evil Geniuses         Liquid      11219
# 2       2020-02-26       EliGE         Liquid  Evil Geniuses       8738
# 3       2020-02-26       Ethan  Evil Geniuses         Liquid      10671
# 4       2020-02-26         NAF         Liquid  Evil Geniuses       8520
# ...            ...         ...            ...            ...        ...
# 383312  2015-10-07      kIMERA        ExAequo      RIP Fonty       7607
# 383313  2015-10-07   morphiw0w        ExAequo      RIP Fonty       9752
# 383314  2015-10-07     overfly      RIP Fonty        ExAequo       7698
# 383315  2015-10-07     simozor      RIP Fonty        ExAequo       9753
# 383316  2015-10-07       xullE      RIP Fonty        ExAequo       9754
#
#         match_id  event_id  best_of        map_1  m1_kills  m1_assists  \
# ...

# %%
map_1_df = map_1_df.dropna()

# %%
map_2_df = players_df[[
    'date',
    'player_name',
    'team',
    'opponent', 
    'player_id', 
    'match_id',
    'event_id',
    'best_of',
    'map_2',
    'm2_kills',
    'm2_assists',
    'm2_deaths',
    'm2_hs',
    'm2_flash_assists',
    'm2_kast',
    'm2_kddiff',
    'm2_adr',
    'm2_fkdiff',
    'm2_rating']].copy()
map_2_df
# Out:
#               date player_name           team       opponent  player_id  \
# 0       2020-02-26      Brehze  Evil Geniuses         Liquid       9136
# 1       2020-02-26        CeRq  Evil Geniuses         Liquid      11219
# 2       2020-02-26       EliGE         Liquid  Evil Geniuses       8738
# 3       2020-02-26       Ethan  Evil Geniuses         Liquid      10671
# 4       2020-02-26         NAF         Liquid  Evil Geniuses       8520
# ...            ...         ...            ...            ...        ...
# 383312  2015-10-07      kIMERA        ExAequo      RIP Fonty       7607
# 383313  2015-10-07   morphiw0w        ExAequo      RIP Fonty       9752
# 383314  2015-10-07     overfly      RIP Fonty        ExAequo       7698
# 383315  2015-10-07     simozor      RIP Fonty        ExAequo       9753
# 383316  2015-10-07       xullE      RIP Fonty        ExAequo       9754
#
#         match_id  event_id  best_of  map_2  m2_kills  m2_assists  m2_deaths  \
# ...

# %%
map_2_df = map_2_df.dropna()

# %%
map_3_df = players_df[[
    'date',
    'player_name',
    'team',
    'opponent', 
    'player_id', 
    'match_id',
    'event_id',
    'best_of',
    'map_3',
    'm3_kills',
    'm3_assists',
    'm3_deaths',
    'm3_hs',
    'm3_flash_assists',
    'm3_kast',
    'm3_kddiff',
    'm3_adr',
    'm3_fkdiff',
    'm3_rating']].copy()
map_3_df
# Out:
#               date player_name           team       opponent  player_id  \
# 0       2020-02-26      Brehze  Evil Geniuses         Liquid       9136
# 1       2020-02-26        CeRq  Evil Geniuses         Liquid      11219
# 2       2020-02-26       EliGE         Liquid  Evil Geniuses       8738
# 3       2020-02-26       Ethan  Evil Geniuses         Liquid      10671
# 4       2020-02-26         NAF         Liquid  Evil Geniuses       8520
# ...            ...         ...            ...            ...        ...
# 383312  2015-10-07      kIMERA        ExAequo      RIP Fonty       7607
# 383313  2015-10-07   morphiw0w        ExAequo      RIP Fonty       9752
# 383314  2015-10-07     overfly      RIP Fonty        ExAequo       7698
# 383315  2015-10-07     simozor      RIP Fonty        ExAequo       9753
# 383316  2015-10-07       xullE      RIP Fonty        ExAequo       9754
#
#         match_id  event_id  best_of    map_3  m3_kills  m3_assists  m3_deaths  \
# ...

# %%
map_3_df = map_3_df.dropna()

# %%
map_3_df.columns
# Out:
# Index(['date', 'player_name', 'team', 'opponent', 'player_id', 'match_id',
#        'event_id', 'best_of', 'map_3', 'm3_kills', 'm3_assists', 'm3_deaths',
#        'm3_hs', 'm3_flash_assists', 'm3_kast', 'm3_kddiff', 'm3_adr',
#        'm3_fkdiff', 'm3_rating'],
#       dtype='object')

# %%
rename_column_headers = ['date',
    'player_name',
    'team', 
    'opponent',
    'player_id',
    'match_id',
    'event_id',
    'best_of',
    'map',
    'kills',
    'assists',
    'deaths',
    'hs',
    'flash_assists',
    'kast',
    'kddiff',
    'adr',
    'fkdiff',
    'rating']

# Change column headers
map_1_df.columns = (rename_column_headers)
map_2_df.columns = (rename_column_headers)
map_3_df.columns = (rename_column_headers)

# %%
frames = [map_1_df, map_2_df, map_3_df]

revised_players = pd.concat(frames)

# %%
player_running_averages = revised_players.sort_values(['player_id','map','date'])

# %%
player_running_averages
# Out:
#               date player_name           team         opponent  player_id  \
# 359523  2016-03-12       Friis             SK             FaZe          7
# 280188  2017-04-18       Friis        Tricked             SFTO          7
# 267010  2017-05-31       Friis        Tricked            PENTA          7
# 255059  2017-07-11       Friis  Gux & Friends  ALTERNATE aTTaX          7
# 255131  2017-07-11       Friis  Gux & Friends           Gambit          7
# ...            ...         ...            ...              ...        ...
# 737     2020-02-23      rabbit          Titan         Medieval      20006
# 722     2020-02-23     boskacz   Wisla Krakow              BIG      20007
# 115     2020-02-27       Porky            LND            Rysix      20009
# 119     2020-02-27       shevi            LND            Rysix      20010
# 153     2020-02-26      bichop        FREEROX        Sinisters      20011
#
#         match_id  event_id  best_of      map  kills  assists  deaths    hs  \
# ...

# %%
pk = player_running_averages[['player_id','match_id','date','map','kills','assists','deaths','hs','flash_assists','kast','kddiff','adr','fkdiff','rating']]

# %%
pk = pk.set_index('player_id')

# %%
pk
# Out:
#            match_id        date      map  kills  assists  deaths    hs  \
# player_id
# 7           2301112  2016-03-12    Cache   34.0      5.0    29.0   3.0
# 7           2309816  2017-04-18    Cache   18.0      4.0    19.0   2.0
# 7           2311256  2017-05-31    Cache   17.0      2.0    20.0   6.0
# 7           2312594  2017-07-11    Cache   16.0      3.0    15.0   7.0
# 7           2312579  2017-07-11    Cache   17.0      6.0    19.0   3.0
# ...             ...         ...      ...    ...      ...     ...   ...
# 20006       2339752  2020-02-23     Nuke   26.0      3.0    14.0  13.0
# 20007       2339745  2020-02-23     Nuke    3.0      1.0    16.0   0.0
# 20009       2339813  2020-02-27  Vertigo   14.0      0.0    16.0   7.0
# 20010       2339813  2020-02-27  Vertigo    6.0      1.0    17.0   5.0
# 20011       2339810  2020-02-26   Mirage   13.0      3.0    19.0   9.0
#
#            flash_assists  kast  kddiff   adr  fkdiff  rating
# player_id
# ...

# %%
# Indivdual player stat cumulative average for every map
pk_cum_avg_kills = pk.groupby(['player_id','map']).kills.apply(lambda x : x.expanding(min_periods=1).mean().fillna(x))
pk_cum_avg_assists = pk.groupby(['player_id','map']).assists.apply(lambda x : x.expanding(min_periods=1).mean().fillna(x))
pk_cum_avg_deaths = pk.groupby(['player_id','map']).deaths.apply(lambda x : x.expanding(min_periods=1).mean().fillna(x))
pk_cum_avg_hs = pk.groupby(['player_id','map']).hs.apply(lambda x : x.expanding(min_periods=1).mean().fillna(x))
pk_cum_avg_flash_assists = pk.groupby(['player_id','map']).flash_assists.apply(lambda x : x.expanding(min_periods=1).mean().fillna(x))
pk_cum_avg_kast = pk.groupby(['player_id','map']).kast.apply(lambda x : x.expanding(min_periods=1).mean().fillna(x))
pk_cum_avg_kddiff = pk.groupby(['player_id','map']).kddiff.apply(lambda x : x.expanding(min_periods=1).mean().fillna(x))
pk_cum_avg_adr = pk.groupby(['player_id','map']).adr.apply(lambda x : x.expanding(min_periods=1).mean().fillna(x))
pk_cum_avg_fkdiff = pk.groupby(['player_id','map']).fkdiff.apply(lambda x : x.expanding(min_periods=1).mean().fillna(x))

# %%
pk_cum_avg_rating = pk.groupby(['player_id','map']).rating.apply(lambda x : x.expanding(min_periods=1).mean().fillna(x))

# %%
pk.loc[:,'Rating_Avg_Per_Map'] = pk_cum_avg_rating

# %%
pk.loc[:,'Kill_Avg_Per_Map'] = pk_cum_avg_kills
pk.loc[:,'Assits_Avg_Per_Map'] = pk_cum_avg_assists
pk.loc[:,'Deaths_Avg_Per_Map'] = pk_cum_avg_deaths
pk.loc[:,'HS_Avg_Per_Map'] = pk_cum_avg_hs
pk.loc[:,'Assists_Avg_Per_Map'] = pk_cum_avg_flash_assists
pk.loc[:,'Kast_Avg_Per_Map'] = pk_cum_avg_kast
pk.loc[:,'Kddiff_Avg_Per_Map'] = pk_cum_avg_kddiff
pk.loc[:,'ADR_Avg_Per_Map'] = pk_cum_avg_adr
pk.loc[:,'FKdiff_Avg_Per_Map'] = pk_cum_avg_fkdiff

# %%
player_running_averages = pd.merge(player_running_averages,pk, on=['player_id','match_id','date','map','kills','assists','deaths','hs','flash_assists','kast','kddiff','adr','fkdiff','rating'])

# %%
player_running_averages = player_running_averages.sort_values(['player_id','date'])

# %%
pk = player_running_averages[['player_id','match_id','date','map','kills','assists','deaths','hs','flash_assists','kast','kddiff','adr','fkdiff','rating']]

# %%
pk = pk.set_index('player_id')

# %%
pk_overall_avg_rating = pk.groupby(['player_id']).rating.apply(lambda x : x.expanding(min_periods=1).mean().fillna(x))

# %%
# Individual players stat cumulative average from earliest date to most current
pk_overall_avg_kills = pk.groupby(['player_id']).kills.apply(lambda x : x.expanding(min_periods=1).mean().fillna(x))
pk_overall_avg_assists = pk.groupby(['player_id']).assists.apply(lambda x : x.expanding(min_periods=1).mean().fillna(x))
pk_overall_avg_deaths = pk.groupby(['player_id']).deaths.apply(lambda x : x.expanding(min_periods=1).mean().fillna(x))
pk_overall_avg_hs = pk.groupby(['player_id']).hs.apply(lambda x : x.expanding(min_periods=1).mean().fillna(x))
pk_overall_avg_flash_assists = pk.groupby(['player_id']).flash_assists.apply(lambda x : x.expanding(min_periods=1).mean().fillna(x))
pk_overall_avg_kast = pk.groupby(['player_id']).kast.apply(lambda x : x.expanding(min_periods=1).mean().fillna(x))
pk_overall_avg_kddiff = pk.groupby(['player_id']).kddiff.apply(lambda x : x.expanding(min_periods=1).mean().fillna(x))
pk_overall_avg_adr = pk.groupby(['player_id']).adr.apply(lambda x : x.expanding(min_periods=1).mean().fillna(x))
pk_overall_avg_fkdiff = pk.groupby(['player_id']).fkdiff.apply(lambda x : x.expanding(min_periods=1).mean().fillna(x))

# %%
pk.loc[:,'Rating_Avg_Overall'] = pk_overall_avg_rating

# %%
pk.loc[:,'Kill_Avg_Overall'] = pk_overall_avg_kills
pk.loc[:,'Assits_Avg_Overall'] = pk_overall_avg_assists
pk.loc[:,'Deaths_Avg_Overall'] = pk_overall_avg_deaths
pk.loc[:,'HS_Avg_Overall'] = pk_overall_avg_hs
pk.loc[:,'Assists_Avg_Overall'] = pk_overall_avg_flash_assists
pk.loc[:,'Kast_Avg_Overall'] = pk_overall_avg_kast
pk.loc[:,'Kddiff_Avg_Overall'] = pk_overall_avg_kddiff
pk.loc[:,'ADR_Avg_Overall'] = pk_overall_avg_adr
pk.loc[:,'FKdiff_Avg_Overall'] = pk_overall_avg_fkdiff

# %%
player_running_averages = pd.merge(player_running_averages,pk, on=['player_id','match_id','date','map','kills','assists','deaths','hs','flash_assists','kast','kddiff','adr','fkdiff','rating'])

# %%
player_running_averages
# Out:
#               date player_name          team    opponent  player_id  match_id  \
# 0       2016-03-10       Friis            SK  E-frag.net          7   2301254
# 1       2016-03-12       Friis            SK        FaZe          7   2301112
# 2       2016-03-13       Friis            SK     Ancient          7   2301320
# 3       2016-03-15       Friis            SK     Tricked          7   2301358
# 4       2016-03-19       Friis            SK         NiP          7   2301377
# ...            ...         ...           ...         ...        ...       ...
# 448706  2020-02-23      rabbit         Titan    Medieval      20006   2339752
# 448707  2020-02-23     boskacz  Wisla Krakow         BIG      20007   2339745
# 448708  2020-02-27       Porky           LND       Rysix      20009   2339813
# 448709  2020-02-27       shevi           LND       Rysix      20010   2339813
# 448710  2020-02-26      bichop       FREEROX   Sinisters      20011   2339810
#
# ...

# %%
pd.set_option('display.max_columns', None)
player_running_averages
# Out:
#               date player_name          team    opponent  player_id  match_id  \
# 0       2016-03-10       Friis            SK  E-frag.net          7   2301254
# 1       2016-03-12       Friis            SK        FaZe          7   2301112
# 2       2016-03-13       Friis            SK     Ancient          7   2301320
# 3       2016-03-15       Friis            SK     Tricked          7   2301358
# 4       2016-03-19       Friis            SK         NiP          7   2301377
# ...            ...         ...           ...         ...        ...       ...
# 448706  2020-02-23      rabbit         Titan    Medieval      20006   2339752
# 448707  2020-02-23     boskacz  Wisla Krakow         BIG      20007   2339745
# 448708  2020-02-27       Porky           LND       Rysix      20009   2339813
# 448709  2020-02-27       shevi           LND       Rysix      20010   2339813
# 448710  2020-02-26      bichop       FREEROX   Sinisters      20011   2339810
#
# ...

# %%
player_running_averages.columns
# Out:
# Index(['date', 'player_name', 'team', 'opponent', 'player_id', 'match_id',
#        'event_id', 'best_of', 'map', 'kills', 'assists', 'deaths', 'hs',
#        'flash_assists', 'kast', 'kddiff', 'adr', 'fkdiff', 'rating',
#        'Kill_Avg_Per_Map', 'Assits_Avg_Per_Map', 'Deaths_Avg_Per_Map',
#        'HS_Avg_Per_Map', 'Assists_Avg_Per_Map', 'Kast_Avg_Per_Map',
#        'Kddiff_Avg_Per_Map', 'ADR_Avg_Per_Map', 'FKdiff_Avg_Per_Map',
#        'Kill_Avg_Overall', 'Assits_Avg_Overall', 'Deaths_Avg_Overall',
#        'HS_Avg_Overall', 'Assists_Avg_Overall', 'Kast_Avg_Overall',
#        'Kddiff_Avg_Overall', 'ADR_Avg_Overall', 'FKdiff_Avg_Overall'],
#       dtype='object')

# %%
column_headers = ['match_id','date', 'player_name', 'team', 'opponent', 'player_id',
       'event_id', 'best_of', 'map', 'kills', 'assists', 'deaths', 'hs',
       'flash_assists', 'kast', 'kddiff', 'adr', 'fkdiff', 'rating',
       'Kill_Avg_Per_Map', 'Assits_Avg_Per_Map', 'Deaths_Avg_Per_Map',
       'HS_Avg_Per_Map', 'Assists_Avg_Per_Map', 'Kast_Avg_Per_Map',
       'Kddiff_Avg_Per_Map', 'ADR_Avg_Per_Map', 'FKdiff_Avg_Per_Map',
       'Kill_Avg_Overall', 'Assits_Avg_Overall', 'Deaths_Avg_Overall',
       'HS_Avg_Overall', 'Assists_Avg_Overall', 'Kast_Avg_Overall',
       'Kddiff_Avg_Overall', 'ADR_Avg_Overall', 'FKdiff_Avg_Overall']

# %%
import datetime

player_running_averages['date'] = pd.to_datetime(player_running_averages['date'])

# %%
player_running_averages2 = pd.merge(player_running_averages,pk, on=['player_id','match_id','date','map','kills','assists','deaths','hs','flash_assists','kast','kddiff','adr','fkdiff','rating'])

# %%
import datetime

player_running_averages2['date'] = pd.to_datetime(player_running_averages2['date'])

# %%
player_running_averages = player_running_averages[column_headers]
player_running_averages.dtypes
# Out:
# match_id                        int64
# date                   datetime64[ns]
# player_name                    object
# team                           object
# opponent                       object
# player_id                       int64
# event_id                        int64
# best_of                         int64
# map                            object
# kills                         float64
# assists                       float64
# deaths                        float64
# hs                            float64
# flash_assists                 float64
# kast                          float64
# kddiff                        float64
# adr                           float64
# fkdiff                        float64
# rating                        float64
# Kill_Avg_Per_Map              float64
# Assits_Avg_Per_Map            float64
# Deaths_Avg_Per_Map            float64
# HS_Avg_Per_Map                float64
# Assists_Avg_Per_Map           float64
# Kast_Avg_Per_Map              float64
# ...

# %%
player_running_averages
# Out:
#         match_id       date player_name          team    opponent  player_id  \
# 0        2301254 2016-03-10       Friis            SK  E-frag.net          7
# 1        2301112 2016-03-12       Friis            SK        FaZe          7
# 2        2301320 2016-03-13       Friis            SK     Ancient          7
# 3        2301358 2016-03-15       Friis            SK     Tricked          7
# 4        2301377 2016-03-19       Friis            SK         NiP          7
# ...          ...        ...         ...           ...         ...        ...
# 448706   2339752 2020-02-23      rabbit         Titan    Medieval      20006
# 448707   2339745 2020-02-23     boskacz  Wisla Krakow         BIG      20007
# 448708   2339813 2020-02-27       Porky           LND       Rysix      20009
# 448709   2339813 2020-02-27       shevi           LND       Rysix      20010
# 448710   2339810 2020-02-26      bichop       FREEROX   Sinisters      20011
#
# ...

# %%
import sqlalchemy  # Package for accessing SQL databases via Python
import psycopg2

# Connect to database (Note: The package psychopg2 is required for Postgres to work with SQLAlchemy)
engine = sqlalchemy.create_engine(f"postgresql://postgres:{password}@dataviz.cdhexjpu5mat.us-east-2.rds.amazonaws.com:{port}/CSGO_project")
con = engine.connect()

# Verify that there are no existing tables
print(engine.table_names())
# Out:
# ['Matches', 'Maps', 'Team_results', 'Players']

# %%
player_running_averages.to_csv('players_extended_stats_rating_addition.csv')

# %%
player_running_averages.to_csv('players_extended_stats.csv')

# %%
import time
table_name = 'Players'
start_time = time.time()
player_running_averages.to_sql(table_name, con, if_exists='replace',method='multi', index=False)
print("--- %s seconds ---" % (time.time() - start_time))
