# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# %% [markdown]
# ## Setting up connection to SQL Database

# %%
engine = create_engine("postgres://postgres:%XhB70dIxJ*C@dataviz.cdhexjpu5mat.us-east-2.rds.amazonaws.com:5432/CSGO_project")
Base = automap_base()
Base.prepare(engine, reflect=True)

# %% [markdown]
# ### Calling Tables from Database
# ###### *Note data tables from data base need to be lower case!

# %% [markdown]
# #### Method 1: Calling data tables from SQL using SQL Code (You do not need a primary key for this to work)

# %%
maptableresults = engine.execute("Select * from maps")
for r in maptableresults:
    print(r)
# Out:
# ('Dust2',)
# ('Inferno',)
# ('Vertigo',)
# ('Overpass',)
# ('Nuke',)
# ('Mirage',)
# ('Train',)
# ('Default',)
# ('Cache',)
# ('Cobblestone',)

# %% [markdown]
# #### Method 2: Calling data tables using Base.classes. (You need to assign a primary key in order to call data tables)

# %%
# requesting specific data tables from database and storing them into variables:
maps = Base.classes.maps
teams = Base.classes.teams

# %%
# Starting the session
session = Session(engine)

# %% [markdown]
# #### Data Table: Maps

# %%
# Method A: Selecting all data in data table and setting it into a list/dictionary 
mapname = session.query(maps).all()
mapnamedata = [{"map": m.map} for m in mapname]
mapnamedata
# Out:
# [{'map': 'Dust2'},
#  {'map': 'Inferno'},
#  {'map': 'Vertigo'},
#  {'map': 'Overpass'},
#  {'map': 'Nuke'},
#  {'map': 'Mirage'},
#  {'map': 'Train'},
#  {'map': 'Default'},
#  {'map': 'Cache'},
#  {'map': 'Cobblestone'}]

# %%
# Method B: Selecting all data in data table and printing out the list of values in the data table.
mapname = session.query(maps).all()
[m.map for m in mapname]
# Out:
# ['Dust2',
#  'Inferno',
#  'Vertigo',
#  'Overpass',
#  'Nuke',
#  'Mirage',
#  'Train',
#  'Default',
#  'Cache',
#  'Cobblestone']

# %% [markdown]
# #### Data Table: Teams

# %%
teamsnames = session.query(teams).all()
teamnamedata = [{"team": m.team} for m in teamsnames]
teamnamedata
# Out:
# []

# %% [markdown]
# #### Data Table: team_results

# %%
##### team results cannot be accessed using: team_result = Base.classes.team_results, because there is no primary key.
##### Therefore, we will use method 1:

# %%
team_resultstest = engine.execute("Select * from team_results")
results1_team_results = [{"team": m.team, 
                          "map": m.map, 
                          "rounds_won": m.rounds_won,
                          "map_winner": m.map_winner,
                          "starting_ct": m.starting_ct,
                          "rounds_won_ct": m.rounds_won_ct,
                          "rounds_won_t": m.rounds_won_t,
                          "rank": m.rank,
                          "map_wins": m.map_wins,
                          "match_winner": m.match_winner,
                         } for m in team_resultstest]
results1_team_results
# Out:
# [{'team': 'Recon 5',
#   'map': 'Dust2',
#   'rounds_won': 0,
#   'map_winner': 'L',
#   'starting_ct': 'No',
#   'rounds_won_ct': 0,
#   'rounds_won_t': 0,
#   'rank': 62,
#   'map_wins': 0,
#   'match_winner': 'L'},
#  {'team': 'Recon 5',
#   'map': 'Inferno',
#   'rounds_won': 13,
#   'map_winner': 'L',
#   'starting_ct': 'No',
#   'rounds_won_ct': 8,
#   'rounds_won_t': 5,
#   'rank': 62,
#   'map_wins': 0,
#   'match_winner': 'L'},
#  {'team': 'New England Whalers',
#   'map': 'Inferno',
#   'rounds_won': 12,
#   'map_winner': 'L',
#   'starting_ct': 'Yes',
#   'rounds_won_ct': 9,
#   'rounds_won_t': 3,
#   'rank': 140,
#   'map_wins': 12,
#   'match_winner': 'L'},
#  {'team': 'Rugratz',
#   'map': 'Inferno',
#   'rounds_won': 7,
#   'map_winner': 'L',
#   'starting_ct': 'No',
#   'rounds_won_ct': 0,
#   'rounds_won_t': 7,
#   'rank': 61,
#   'map_wins': 0,
#   'match_winner': 'L'},
#  {'team': 'Rugratz',
#   'map': 'Vertigo',
#   'rounds_won': 8,
#   'map_winner': 'L',
# ...

# %%
# Row check to make sure I have the correct amount of data:
df = pd.DataFrame(results1_team_results)
print(df)

# %% [markdown]
# #### This would be entered into a python app.py file to run it with our flask/html webpage
